# %% [markdown]
# #### Step 6 :- So on these notebooks we are gonna train ,test split and class imbalance
# ###### Input :- Insert the scaled_collision dataset
# ###### Process :- We will work on training and splitting , class imbalance
# ###### Output :-

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
df = pd.read_csv('../Data/Scaled_collision.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 503373 entries, 0 to 503372
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   collision_year              503373 non-null  int64
#  1   longitude                   503373 non-null  float64
#  2   latitude                    503373 non-null  float64
#  3   collision_severity          503373 non-null  int64
#  4   number_of_vehicles          503373 non-null  float64
#  5   number_of_casualties        503373 non-null  float64
#  6   day_of_week                 503373 non-null  int64
#  7   first_road_class            503373 non-null  int64
#  8   road_type                   503373 non-null  int64
#  9   speed_limit                 503373 non-null  float64
#  10  junction_detail             503373 non-null  float64
#  11  second_road_class           503373 non-null  float64
#  12  pedestrian_crossing         503373 non-null  float64
#  13  light_conditions            503373 non-null  float64
#  14  weather_conditions          503373 non-null  float64
#  15  road_surface_conditions     503373 non-null  float64
#  16  special_conditions_at_site  503373 non-null  float64
#  17  carriageway_hazards         503373 non-null  float64
#  18  urban_or_rural_area         503373 non-null  float64
#  19  hour                        503373 non-null  float64
#  20  month                       503373 non-null  float64
#  21  season                      503373 non-null  int64
#  22  is_rush_hour                503373 non-null  int64
#  23  is_weekend                  503373 non-null  int64
#  24  is_dark                     503373 non-null  int64
#  25  is_bad_weather              503373 non-null  int64
#  26  is_highspeed                503373 non-null  int64
#  27  is_urban                    503373 non-null  int64
#  28  is_junction                 503373 non-null  int64
#  29  is_hazards                  503373 non-null  int64
# dtypes: float64(16), int64(14)
# memory usage: 115.2 MB

# %%
X = df.drop(['collision_year','season','collision_severity'],axis=1)
y= df['collision_severity']
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
print(X_train)
# Out:
#         longitude  latitude  number_of_vehicles  number_of_casualties  \
# 38902   -1.345568  2.901334           -1.208831             -0.389663
# 396340  -2.603416  2.771025            0.249926             -0.389663
# 298511  -1.270275 -0.340604           -1.208831             -0.389663
# 122079  -0.300136  1.987310           -1.208831             -0.389663
# 488449  -0.611117 -1.229316            0.249926             -0.389663
# ...           ...       ...                 ...                   ...
# 364257   0.099289 -1.185741           -1.208831             -0.389663
# 58232   -0.680924  0.324787            1.708684             -0.389663
# 351406  -0.930729  0.667478            0.249926             -0.389663
# 97137   -0.194176  0.120897            0.249926             -0.389663
# 386433  -0.491605  0.077256            0.249926             -0.389663
#
#         day_of_week  first_road_class  road_type  speed_limit  \
# 38902             3                 6          6    -1.123833
# 396340            1                 6          6    -0.421116
# 298511            7                 3          6     1.687033
# 122079            7                 6          6    -1.123833
# 488449            3                 3          1     1.687033
# ...             ...               ...        ...          ...
# 364257            2                 6          6    -0.421116
# 58232             5                 6          6    -0.421116
# 351406            6                 3          6     1.687033
# 97137             1                 3          1    -0.421116
# 386433            6                 6          6    -0.421116
#
#         junction_detail  second_road_class  ...      hour     month  \
# 38902              16.0                6.0  ...  0.046804 -1.078864
# 396340             16.0                6.0  ...  0.241385 -0.786244
# 298511              0.0                0.0  ... -0.926100 -0.201004
# 122079              0.0                0.0  ...  1.408870 -1.664103
# 488449              0.0                3.0  ... -0.731519 -0.786244
# ...                 ...                ...  ...       ...       ...
# 364257              0.0                0.0  ...  1.019708 -0.786244
# 58232              13.0                6.0  ...  0.630546 -0.786244
# 351406             16.0                6.0  ...  1.214289 -1.078864
# 97137               0.0                3.0  ...  0.046804  0.676855
# 386433             19.0                6.0  ...  1.798031  1.262095
#
#         is_rush_hour  is_weekend  is_dark  is_bad_weather  is_highspeed  \
# 38902              0           0        0               0             0
# 396340             0           1        0               0             0
# 298511             1           1        0               0             1
# 122079             0           1        1               0             0
# 488449             0           0        0               0             1
# ...              ...         ...      ...             ...           ...
# 364257             1           0        0               0             0
# 58232              1           0        0               0             0
# 351406             0           0        1               0             1
# 97137              0           1        0               0             0
# 386433             0           0        1               0             0
#
#         is_urban  is_junction  is_hazards
# 38902          1            1           0
# 396340         1            1           0
# 298511         0            0           0
# 122079         1            0           0
# 488449         0            0           0
# ...          ...          ...         ...
# 364257         1            0           0
# 58232          1            1           0
# 351406         0            1           0
# 97137          1            0           0
# 386433         1            1           0
#
# [402698 rows x 27 columns]

# %%
print(X_test)
# Out:
#         longitude  latitude  number_of_vehicles  number_of_casualties  \
# 227323   0.805100 -0.578147            0.249926             -0.389663
# 327531  -0.731919  0.824480           -1.208831             -0.389663
# 105660   0.725280 -0.665892           -1.208831             -0.389663
# 236528   0.691501 -0.529261            0.249926             -0.389663
# 306808  -0.755735  1.088880           -1.208831             -0.389663
# ...           ...       ...                 ...                   ...
# 111746   0.739215 -0.719646            0.249926             -0.389663
# 112509   0.595904 -1.153579           -1.208831             -0.389663
# 486011  -1.002660 -0.710131            0.249926             -0.389663
# 100219  -0.553937  0.089797            0.249926              1.041755
# 492005   0.744290 -0.645184            0.249926             -0.389663
#
#         day_of_week  first_road_class  road_type  speed_limit  \
# 227323            3                 3          3    -0.421116
# 327531            7                 3          6    -0.421116
# 105660            5                 3          9    -0.421116
# 236528            6                 4          6    -0.421116
# 306808            3                 6          6    -0.421116
# ...             ...               ...        ...          ...
# 111746            3                 3          9    -0.421116
# 112509            4                 6          6    -0.421116
# 486011            4                 3          6    -0.421116
# 100219            4                 4          6    -0.421116
# 492005            7                 6          6    -1.123833
#
#         junction_detail  second_road_class  ...      hour     month  \
# 227323             13.0                5.0  ...  0.435966  1.554715
# 327531             16.0                6.0  ...  1.408870  0.676855
# 105660             13.0                6.0  ... -0.147777 -0.201004
# 236528              0.0                6.0  ... -1.315262 -1.664103
# 306808              0.0                0.0  ...  0.241385  0.969475
# ...                 ...                ...  ...       ...       ...
# 111746             13.0                6.0  ... -0.731519  0.384236
# 112509             13.0                6.0  ... -0.342358 -1.371483
# 486011             13.0                6.0  ... -1.509843  0.969475
# 100219              0.0                0.0  ... -2.093585 -1.078864
# 492005              0.0                6.0  ...  0.241385 -1.371483
#
#         is_rush_hour  is_weekend  is_dark  is_bad_weather  is_highspeed  \
# 227323             0           0        1               1             0
# 327531             0           1        1               1             0
# 105660             0           0        0               0             0
# 236528             1           0        0               0             0
# 306808             0           0        0               1             0
# ...              ...         ...      ...             ...           ...
# 111746             0           0        0               0             0
# 112509             0           0        0               0             0
# 486011             0           0        1               0             0
# 100219             0           0        1               0             0
# 492005             0           1        0               0             0
#
#         is_urban  is_junction  is_hazards
# 227323         1            1           0
# 327531         1            1           0
# 105660         1            1           1
# 236528         1            0           0
# 306808         0            0           0
# ...          ...          ...         ...
# 111746         1            1           1
# 112509         1            1           0
# 486011         1            1           0
# 100219         1            0           0
# 492005         1            0           0
#
# [100675 rows x 27 columns]

# %%
np.save('../Data/X_train.npy',X_train)
np.save('../Data/X_test.npy',X_test)
np.save('../Data/Y_train.npy',Y_train)
np.save('../Data/Y_test.npy',Y_test)

df2 = pd.Series(Y_train).value_counts(normalize=True).sort_index()

# %%
print(df2*100)
# Out:
# collision_severity
# 1     1.487219
# 2    21.842920
# 3    76.669862
# Name: proportion, dtype: float64

# %% [markdown]
# #####
